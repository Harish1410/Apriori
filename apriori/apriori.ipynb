# %% [markdown]
# # Apriori

# %% [markdown]
# ## Importing the libraries

# %%
# !pip install apyori
# Out:
# Requirement already satisfied: apyori in c:\users\harry\appdata\local\programs\python\python310\lib\site-packages (1.1.2)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Data Preprocessing

# %%
dataset = pd.read_csv('D:\AML\Mall_Customers.csv', header = None)
transactions = []
for i in range(0, 200):
  transactions.append([str(dataset.values[i,j]) for j in range(0, 5)])

# %% [markdown]
# ## Training the Apriori model on the dataset

# %%
from apyori import apriori
rules = apriori(transactions = transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)
print(rules)
# Out:
# <generator object apriori at 0x00000279E32D9D20>

# %% [markdown]
# ## Visualising the results

# %% [markdown]
# ### Displaying the first results coming directly from the output of the apriori function

# %%
results = list(rules)

# %%
results
# Out:
# [RelationRecord(items=frozenset({'15', '1'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'1'}), items_add=frozenset({'15'}), confidence=0.33333333333333337, lift=11.111111111111112)]),
#  RelationRecord(items=frozenset({'157', '1'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'1'}), items_add=frozenset({'157'}), confidence=0.33333333333333337, lift=66.66666666666667), OrderedStatistic(items_base=frozenset({'157'}), items_add=frozenset({'1'}), confidence=1.0, lift=66.66666666666667)]),
#  RelationRecord(items=frozenset({'159', '1'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'1'}), items_add=frozenset({'159'}), confidence=0.33333333333333337, lift=66.66666666666667), OrderedStatistic(items_base=frozenset({'159'}), items_add=frozenset({'1'}), confidence=1.0, lift=66.66666666666667)]),
#  RelationRecord(items=frozenset({'19', '1'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'1'}), items_add=frozenset({'19'}), confidence=0.33333333333333337, lift=5.128205128205129)]),
#  RelationRecord(items=frozenset({'34', '1'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'1'}), items_add=frozenset({'34'}), confidence=0.33333333333333337, lift=7.407407407407408)]),
#  RelationRecord(items=frozenset({'37', '1'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'1'}), items_add=frozenset({'37'}), confidence=0.33333333333333337, lift=11.111111111111112)]),
#  RelationRecord(items=frozenset({'39', '1'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'1'}), items_add=frozenset({'39'}), confidence=0.33333333333333337, lift=6.666666666666667)]),
#  RelationRecord(items=frozenset({'78', '1'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'1'}), items_add=frozenset({'78'}), confidence=0.6666666666666667, lift=10.256410256410257)]),
#  RelationRecord(items=frozenset({'139', '10'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'10'}), items_add=frozenset({'139'}), confidence=0.33333333333333337, lift=66.66666666666667), OrderedStatistic(items_base=frozenset({'139'}), items_add=frozenset({'10'}), confidence=1.0, lift=66.66666666666667)]),
#  RelationRecord(items=frozenset({'173', '10'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'10'}), items_add=frozenset({'173'}), confidence=0.33333333333333337, lift=66.66666666666667), OrderedStatistic(items_base=frozenset({'173'}), items_add=frozenset({'10'}), confidence=1.0, lift=66.66666666666667)]),
#  RelationRecord(items=frozenset({'19', '10'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'10'}), items_add=frozenset({'19'}), confidence=0.6666666666666667, lift=10.256410256410257)]),
#  RelationRecord(items=frozenset({'30', '10'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'10'}), items_add=frozenset({'30'}), confidence=0.33333333333333337, lift=7.407407407407408)]),
#  RelationRecord(items=frozenset({'36', '10'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'10'}), items_add=frozenset({'36'}), confidence=0.33333333333333337, lift=7.407407407407408)]),
#  RelationRecord(items=frozenset({'72', '10'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'10'}), items_add=frozenset({'72'}), confidence=0.33333333333333337, lift=13.333333333333334)]),
#  RelationRecord(items=frozenset({'74', '10'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'10'}), items_add=frozenset({'74'}), confidence=0.33333333333333337, lift=13.333333333333334)]),
#  RelationRecord(items=frozenset({'87', '10'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'10'}), items_add=frozenset({'87'}), confidence=0.33333333333333337, lift=7.407407407407408)]),
#  RelationRecord(items=frozenset({'100', '20'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'100'}), items_add=frozenset({'20'}), confidence=1.0, lift=16.666666666666668)]),
#  RelationRecord(items=frozenset({'100', '49'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'100'}), items_add=frozenset({'49'}), confidence=1.0, lift=15.384615384615383)]),
#  RelationRecord(items=frozenset({'100', '61'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'100'}), items_add=frozenset({'61'}), confidence=1.0, lift=40.0)]),
#  RelationRecord(items=frozenset({'187', '101'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'101'}), items_add=frozenset({'187'}), confidence=0.33333333333333337, lift=66.66666666666667), OrderedStatistic(items_base=frozenset({'187'}), items_add=frozenset({'101'}), confidence=1.0, lift=66.66666666666667)]),
#  RelationRecord(items=frozenset({'188', '101'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'101'}), items_add=frozenset({'188'}), confidence=0.33333333333333337, lift=66.66666666666667), OrderedStatistic(items_base=frozenset({'188'}), items_add=frozenset({'101'}), confidence=1.0, lift=66.66666666666667)]),
#  RelationRecord(items=frozenset({'23', '101'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'101'}), items_add=frozenset({'23'}), confidence=0.33333333333333337, lift=6.666666666666667)]),
#  RelationRecord(items=frozenset({'24', '101'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'101'}), items_add=frozenset({'24'}), confidence=0.33333333333333337, lift=8.333333333333334)]),
#  RelationRecord(items=frozenset({'28', '101'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'101'}), items_add=frozenset({'28'}), confidence=0.33333333333333337, lift=6.666666666666667)]),
#  RelationRecord(items=frozenset({'41', '101'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'101'}), items_add=frozenset({'41'}), confidence=0.33333333333333337, lift=9.523809523809524)]),
#  RelationRecord(items=frozenset({'54', '101'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'101'}), items_add=frozenset({'54'}), confidence=0.33333333333333337, lift=3.5087719298245617)]),
#  RelationRecord(items=frozenset({'62', '101'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'101'}), items_add=frozenset({'62'}), confidence=0.33333333333333337, lift=9.523809523809524)]),
#  RelationRecord(items=frozenset({'68', '101'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'101'}), items_add=frozenset({'68'}), confidence=0.33333333333333337, lift=16.666666666666668), OrderedStatistic(items_base=frozenset({'68'}), items_add=frozenset({'101'}), confidence=0.25, lift=16.666666666666668)]),
#  RelationRecord(items=frozenset({'102', '48'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'102'}), items_add=frozenset({'48'}), confidence=1.0, lift=12.5)]),
#  RelationRecord(items=frozenset({'102', '49'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'102'}), items_add=frozenset({'49'}), confidence=1.0, lift=15.384615384615383)]),
#  RelationRecord(items=frozenset({'102', '62'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'102'}), items_add=frozenset({'62'}), confidence=1.0, lift=28.57142857142857)]),
#  RelationRecord(items=frozenset({'103', '189'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'189'}), items_add=frozenset({'103'}), confidence=1.0, lift=40.0)]),
#  RelationRecord(items=frozenset({'103', '190'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'190'}), items_add=frozenset({'103'}), confidence=1.0, lift=40.0)]),
#  RelationRecord(items=frozenset({'103', '191'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'191'}), items_add=frozenset({'103'}), confidence=1.0, lift=40.0)]),
#  RelationRecord(items=frozenset({'103', '192'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'192'}), items_add=frozenset({'103'}), confidence=1.0, lift=40.0)]),
#  RelationRecord(items=frozenset({'103', '85'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'85'}), items_add=frozenset({'103'}), confidence=0.25, lift=10.0)]),
#  RelationRecord(items=frozenset({'26', '104'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'104'}), items_add=frozenset({'26'}), confidence=1.0, lift=40.0)]),
#  RelationRecord(items=frozenset({'104', '55'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'104'}), items_add=frozenset({'55'}), confidence=1.0, lift=22.22222222222222)]),
#  RelationRecord(items=frozenset({'104', '62'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'104'}), items_add=frozenset({'62'}), confidence=1.0, lift=28.57142857142857)]),
#  RelationRecord(items=frozenset({'49', '105'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'105'}), items_add=frozenset({'49'}), confidence=1.0, lift=15.384615384615383)]),
#  RelationRecord(items=frozenset({'56', '105'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'105'}), items_add=frozenset({'56'}), confidence=1.0, lift=33.333333333333336)]),
#  RelationRecord(items=frozenset({'105', '62'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'105'}), items_add=frozenset({'62'}), confidence=1.0, lift=28.57142857142857)]),
#  RelationRecord(items=frozenset({'106', '21'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'106'}), items_add=frozenset({'21'}), confidence=1.0, lift=25.0)]),
#  RelationRecord(items=frozenset({'106', '42'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'106'}), items_add=frozenset({'42'}), confidence=1.0, lift=15.384615384615383)]),
#  RelationRecord(items=frozenset({'106', '62'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'106'}), items_add=frozenset({'62'}), confidence=1.0, lift=28.57142857142857)]),
#  RelationRecord(items=frozenset({'107', '50'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'107'}), items_add=frozenset({'50'}), confidence=1.0, lift=15.384615384615383)]),
#  RelationRecord(items=frozenset({'107', '63'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'107'}), items_add=frozenset({'63'}), confidence=1.0, lift=20.0)]),
#  RelationRecord(items=frozenset({'107', '66'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'107'}), items_add=frozenset({'66'}), confidence=1.0, lift=50.0), OrderedStatistic(items_base=frozenset({'66'}), items_add=frozenset({'107'}), confidence=0.25, lift=50.0)]),
#  RelationRecord(items=frozenset({'108', '46'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'108'}), items_add=frozenset({'46'}), confidence=1.0, lift=15.384615384615383)]),
#  RelationRecord(items=frozenset({'108', '54'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'108'}), items_add=frozenset({'54'}), confidence=1.0, lift=10.526315789473685)]),
#  RelationRecord(items=frozenset({'108', '63'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'108'}), items_add=frozenset({'63'}), confidence=1.0, lift=20.0)]),
#  RelationRecord(items=frozenset({'43', '109'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'109'}), items_add=frozenset({'43'}), confidence=1.0, lift=18.181818181818183)]),
#  RelationRecord(items=frozenset({'63', '109'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'109'}), items_add=frozenset({'63'}), confidence=1.0, lift=20.0)]),
#  RelationRecord(items=frozenset({'109', '68'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'109'}), items_add=frozenset({'68'}), confidence=1.0, lift=50.0), OrderedStatistic(items_base=frozenset({'68'}), items_add=frozenset({'109'}), confidence=0.25, lift=50.0)]),
#  RelationRecord(items=frozenset({'11', '129'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'11'}), items_add=frozenset({'129'}), confidence=0.5, lift=100.0), OrderedStatistic(items_base=frozenset({'129'}), items_add=frozenset({'11'}), confidence=1.0, lift=100.0)]),
#  RelationRecord(items=frozenset({'11', '14'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'11'}), items_add=frozenset({'14'}), confidence=0.5, lift=20.0)]),
#  RelationRecord(items=frozenset({'11', '19'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'11'}), items_add=frozenset({'19'}), confidence=0.5, lift=7.692307692307692)]),
#  RelationRecord(items=frozenset({'11', '59'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'11'}), items_add=frozenset({'59'}), confidence=0.5, lift=8.333333333333334)]),
#  RelationRecord(items=frozenset({'11', '67'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'11'}), items_add=frozenset({'67'}), confidence=0.5, lift=11.11111111111111)]),
#  RelationRecord(items=frozenset({'71', '11'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'11'}), items_add=frozenset({'71'}), confidence=0.5, lift=12.5)]),
#  RelationRecord(items=frozenset({'48', '110'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'110'}), items_add=frozenset({'48'}), confidence=1.0, lift=12.5)]),
#  RelationRecord(items=frozenset({'63', '110'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'110'}), items_add=frozenset({'63'}), confidence=1.0, lift=20.0)]),
#  RelationRecord(items=frozenset({'66', '110'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'110'}), items_add=frozenset({'66'}), confidence=1.0, lift=50.0), OrderedStatistic(items_base=frozenset({'66'}), items_add=frozenset({'110'}), confidence=0.25, lift=50.0)]),
#  RelationRecord(items=frozenset({'52', '111'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'111'}), items_add=frozenset({'52'}), confidence=1.0, lift=25.0)]),
#  RelationRecord(items=frozenset({'111', '63'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'111'}), items_add=frozenset({'63'}), confidence=1.0, lift=20.0)]),
#  RelationRecord(items=frozenset({'111', '65'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'111'}), items_add=frozenset({'65'}), confidence=1.0, lift=25.0)]),
#  RelationRecord(items=frozenset({'112', '19'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'112'}), items_add=frozenset({'19'}), confidence=1.0, lift=15.384615384615383)]),
#  RelationRecord(items=frozenset({'112', '54'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'112'}), items_add=frozenset({'54'}), confidence=1.0, lift=10.526315789473685)]),
#  RelationRecord(items=frozenset({'112', '63'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'112'}), items_add=frozenset({'63'}), confidence=1.0, lift=20.0)]),
#  RelationRecord(items=frozenset({'193', '113'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'113'}), items_add=frozenset({'193'}), confidence=0.33333333333333337, lift=66.66666666666667), OrderedStatistic(items_base=frozenset({'193'}), items_add=frozenset({'113'}), confidence=1.0, lift=66.66666666666667)]),
#  RelationRecord(items=frozenset({'113', '194'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'113'}), items_add=frozenset({'194'}), confidence=0.33333333333333337, lift=66.66666666666667), OrderedStatistic(items_base=frozenset({'194'}), items_add=frozenset({'113'}), confidence=1.0, lift=66.66666666666667)]),
#  RelationRecord(items=frozenset({'113', '33'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'113'}), items_add=frozenset({'33'}), confidence=0.33333333333333337, lift=9.523809523809524)]),
#  RelationRecord(items=frozenset({'113', '38'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'113'}), items_add=frozenset({'38'}), confidence=0.6666666666666667, lift=14.814814814814817), OrderedStatistic(items_base=frozenset({'38'}), items_add=frozenset({'113'}), confidence=0.22222222222222224, lift=14.814814814814817)]),
#  RelationRecord(items=frozenset({'113', '42'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'113'}), items_add=frozenset({'42'}), confidence=0.33333333333333337, lift=5.128205128205129)]),
#  RelationRecord(items=frozenset({'113', '64'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'113'}), items_add=frozenset({'64'}), confidence=0.33333333333333337, lift=16.666666666666668), OrderedStatistic(items_base=frozenset({'64'}), items_add=frozenset({'113'}), confidence=0.25, lift=16.666666666666668)]),
#  RelationRecord(items=frozenset({'113', '8'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'113'}), items_add=frozenset({'8'}), confidence=0.33333333333333337, lift=33.333333333333336), OrderedStatistic(items_base=frozenset({'8'}), items_add=frozenset({'113'}), confidence=0.5, lift=33.333333333333336)]),
#  RelationRecord(items=frozenset({'113', '91'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'113'}), items_add=frozenset({'91'}), confidence=0.33333333333333337, lift=22.222222222222225), OrderedStatistic(items_base=frozenset({'91'}), items_add=frozenset({'113'}), confidence=0.33333333333333337, lift=22.222222222222225)]),
#  RelationRecord(items=frozenset({'19', '114'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'114'}), items_add=frozenset({'19'}), confidence=1.0, lift=15.384615384615383)]),
#  RelationRecord(items=frozenset({'46', '114'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'114'}), items_add=frozenset({'46'}), confidence=1.0, lift=15.384615384615383)]),
#  RelationRecord(items=frozenset({'64', '114'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'114'}), items_add=frozenset({'64'}), confidence=1.0, lift=50.0), OrderedStatistic(items_base=frozenset({'64'}), items_add=frozenset({'114'}), confidence=0.25, lift=50.0)]),
#  RelationRecord(items=frozenset({'18', '115'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'115'}), items_add=frozenset({'18'}), confidence=1.0, lift=25.0)]),
#  RelationRecord(items=frozenset({'48', '115'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'115'}), items_add=frozenset({'48'}), confidence=1.0, lift=12.5)]),
#  RelationRecord(items=frozenset({'65', '115'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'115'}), items_add=frozenset({'65'}), confidence=1.0, lift=25.0)]),
#  RelationRecord(items=frozenset({'116', '19'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'116'}), items_add=frozenset({'19'}), confidence=1.0, lift=15.384615384615383)]),
#  RelationRecord(items=frozenset({'116', '50'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'116'}), items_add=frozenset({'50'}), confidence=1.0, lift=15.384615384615383)]),
#  RelationRecord(items=frozenset({'116', '65'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'116'}), items_add=frozenset({'65'}), confidence=1.0, lift=25.0)]),
#  RelationRecord(items=frozenset({'43', '117'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'117'}), items_add=frozenset({'43'}), confidence=1.0, lift=18.181818181818183)]),
#  RelationRecord(items=frozenset({'63', '117'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'117'}), items_add=frozenset({'63'}), confidence=1.0, lift=20.0)]),
#  RelationRecord(items=frozenset({'117', '65'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'117'}), items_add=frozenset({'65'}), confidence=1.0, lift=25.0)]),
#  RelationRecord(items=frozenset({'49', '118'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'118'}), items_add=frozenset({'49'}), confidence=1.0, lift=15.384615384615383)]),
#  RelationRecord(items=frozenset({'118', '59'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'118'}), items_add=frozenset({'59'}), confidence=1.0, lift=16.666666666666668)]),
#  RelationRecord(items=frozenset({'65', '118'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'118'}), items_add=frozenset({'65'}), confidence=1.0, lift=25.0)]),
#  RelationRecord(items=frozenset({'43', '119'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'119'}), items_add=frozenset({'43'}), confidence=1.0, lift=18.181818181818183)]),
#  RelationRecord(items=frozenset({'51', '119'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'119'}), items_add=frozenset({'51'}), confidence=1.0, lift=33.333333333333336)]),
#  RelationRecord(items=frozenset({'67', '119'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'119'}), items_add=frozenset({'67'}), confidence=1.0, lift=22.22222222222222)]),
#  RelationRecord(items=frozenset({'145', '12'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'12'}), items_add=frozenset({'145'}), confidence=0.5, lift=100.0), OrderedStatistic(items_base=frozenset({'145'}), items_add=frozenset({'12'}), confidence=1.0, lift=100.0)]),
#  RelationRecord(items=frozenset({'19', '12'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'12'}), items_add=frozenset({'19'}), confidence=0.5, lift=7.692307692307692)]),
#  RelationRecord(items=frozenset({'25', '12'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'12'}), items_add=frozenset({'25'}), confidence=0.5, lift=16.666666666666668)]),
#  RelationRecord(items=frozenset({'35', '12'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'12'}), items_add=frozenset({'35'}), confidence=0.5, lift=7.692307692307692)]),
#  RelationRecord(items=frozenset({'77', '12'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'12'}), items_add=frozenset({'77'}), confidence=0.5, lift=12.5)]),
#  RelationRecord(items=frozenset({'99', '12'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'12'}), items_add=frozenset({'99'}), confidence=0.5, lift=25.0), OrderedStatistic(items_base=frozenset({'99'}), items_add=frozenset({'12'}), confidence=0.25, lift=25.0)]),
#  RelationRecord(items=frozenset({'16', '120'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'120'}), items_add=frozenset({'16'}), confidence=0.33333333333333337, lift=13.333333333333334)]),
#  RelationRecord(items=frozenset({'120', '195'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'120'}), items_add=frozenset({'195'}), confidence=0.33333333333333337, lift=66.66666666666667), OrderedStatistic(items_base=frozenset({'195'}), items_add=frozenset({'120'}), confidence=1.0, lift=66.66666666666667)]),
#  RelationRecord(items=frozenset({'120', '196'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'120'}), items_add=frozenset({'196'}), confidence=0.33333333333333337, lift=66.66666666666667), OrderedStatistic(items_base=frozenset({'196'}), items_add=frozenset({'120'}), confidence=1.0, lift=66.66666666666667)]),
#  RelationRecord(items=frozenset({'35', '120'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'120'}), items_add=frozenset({'35'}), confidence=0.33333333333333337, lift=5.128205128205129)]),
#  RelationRecord(items=frozenset({'47', '120'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'120'}), items_add=frozenset({'47'}), confidence=0.33333333333333337, lift=5.555555555555556)]),
#  RelationRecord(items=frozenset({'50', '120'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'120'}), items_add=frozenset({'50'}), confidence=0.33333333333333337, lift=5.128205128205129)]),
#  RelationRecord(items=frozenset({'120', '57'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'120'}), items_add=frozenset({'57'}), confidence=0.33333333333333337, lift=9.523809523809524)]),
#  RelationRecord(items=frozenset({'120', '67'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'120'}), items_add=frozenset({'67'}), confidence=0.33333333333333337, lift=7.407407407407408)]),
#  RelationRecord(items=frozenset({'120', '79'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'120'}), items_add=frozenset({'79'}), confidence=0.33333333333333337, lift=13.333333333333334)]),
#  RelationRecord(items=frozenset({'27', '121'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'121'}), items_add=frozenset({'27'}), confidence=1.0, lift=25.0)]),
#  RelationRecord(items=frozenset({'121', '56'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'121'}), items_add=frozenset({'56'}), confidence=1.0, lift=33.333333333333336)]),
#  RelationRecord(items=frozenset({'121', '67'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'121'}), items_add=frozenset({'67'}), confidence=1.0, lift=22.22222222222222)]),
#  RelationRecord(items=frozenset({'122', '38'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'122'}), items_add=frozenset({'38'}), confidence=1.0, lift=22.22222222222222)]),
#  RelationRecord(items=frozenset({'40', '122'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'122'}), items_add=frozenset({'40'}), confidence=1.0, lift=14.285714285714285)]),
#  RelationRecord(items=frozenset({'122', '67'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'122'}), items_add=frozenset({'67'}), confidence=1.0, lift=22.22222222222222)]),
#  RelationRecord(items=frozenset({'40', '123'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'123'}), items_add=frozenset({'40'}), confidence=1.0, lift=14.285714285714285)]),
#  RelationRecord(items=frozenset({'58', '123'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'123'}), items_add=frozenset({'58'}), confidence=1.0, lift=28.57142857142857)]),
#  RelationRecord(items=frozenset({'69', '123'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'123'}), items_add=frozenset({'69'}), confidence=1.0, lift=33.333333333333336)]),
#  RelationRecord(items=frozenset({'124', '39'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'124'}), items_add=frozenset({'39'}), confidence=1.0, lift=20.0)]),
#  RelationRecord(items=frozenset({'69', '124'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'124'}), items_add=frozenset({'69'}), confidence=1.0, lift=33.333333333333336)]),
#  RelationRecord(items=frozenset({'124', '91'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'124'}), items_add=frozenset({'91'}), confidence=1.0, lift=66.66666666666667), OrderedStatistic(items_base=frozenset({'91'}), items_add=frozenset({'124'}), confidence=0.33333333333333337, lift=66.66666666666667)]),
#  RelationRecord(items=frozenset({'125', '23'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'125'}), items_add=frozenset({'23'}), confidence=1.0, lift=20.0)]),
#  RelationRecord(items=frozenset({'29', '125'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'125'}), items_add=frozenset({'29'}), confidence=1.0, lift=22.22222222222222)]),
#  RelationRecord(items=frozenset({'70', '125'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'125'}), items_add=frozenset({'70'}), confidence=1.0, lift=40.0)]),
#  RelationRecord(items=frozenset({'197', '126'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'126'}), items_add=frozenset({'197'}), confidence=0.33333333333333337, lift=66.66666666666667), OrderedStatistic(items_base=frozenset({'197'}), items_add=frozenset({'126'}), confidence=1.0, lift=66.66666666666667)]),
#  RelationRecord(items=frozenset({'126', '198'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'126'}), items_add=frozenset({'198'}), confidence=0.33333333333333337, lift=66.66666666666667), OrderedStatistic(items_base=frozenset({'198'}), items_add=frozenset({'126'}), confidence=1.0, lift=66.66666666666667)]),
#  RelationRecord(items=frozenset({'28', '126'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'126'}), items_add=frozenset({'28'}), confidence=0.33333333333333337, lift=6.666666666666667)]),
#  RelationRecord(items=frozenset({'126', '31'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'126'}), items_add=frozenset({'31'}), confidence=0.33333333333333337, lift=6.666666666666667)]),
#  RelationRecord(items=frozenset({'126', '32'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'126'}), items_add=frozenset({'32'}), confidence=0.33333333333333337, lift=4.761904761904762)]),
#  RelationRecord(items=frozenset({'126', '45'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'126'}), items_add=frozenset({'45'}), confidence=0.33333333333333337, lift=13.333333333333334)]),
#  RelationRecord(items=frozenset({'126', '70'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'126'}), items_add=frozenset({'70'}), confidence=0.33333333333333337, lift=13.333333333333334)]),
#  RelationRecord(items=frozenset({'126', '74'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'126'}), items_add=frozenset({'74'}), confidence=0.33333333333333337, lift=13.333333333333334)]),
#  RelationRecord(items=frozenset({'126', '77'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'126'}), items_add=frozenset({'77'}), confidence=0.33333333333333337, lift=8.333333333333334)]),
#  RelationRecord(items=frozenset({'127', '35'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'127'}), items_add=frozenset({'35'}), confidence=1.0, lift=15.384615384615383)]),
#  RelationRecord(items=frozenset({'127', '43'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'127'}), items_add=frozenset({'43'}), confidence=1.0, lift=18.181818181818183)]),
#  RelationRecord(items=frozenset({'127', '71'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'127'}), items_add=frozenset({'71'}), confidence=1.0, lift=25.0)]),
#  RelationRecord(items=frozenset({'40', '128'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'128'}), items_add=frozenset({'40'}), confidence=1.0, lift=14.285714285714285)]),
#  RelationRecord(items=frozenset({'71', '128'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'128'}), items_add=frozenset({'71'}), confidence=1.0, lift=25.0)]),
#  RelationRecord(items=frozenset({'95', '128'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'128'}), items_add=frozenset({'95'}), confidence=1.0, lift=66.66666666666667), OrderedStatistic(items_base=frozenset({'95'}), items_add=frozenset({'128'}), confidence=0.33333333333333337, lift=66.66666666666667)]),
#  RelationRecord(items=frozenset({'129', '59'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'129'}), items_add=frozenset({'59'}), confidence=1.0, lift=16.666666666666668)]),
#  RelationRecord(items=frozenset({'71', '129'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'129'}), items_add=frozenset({'71'}), confidence=1.0, lift=25.0)]),
#  RelationRecord(items=frozenset({'15', '13'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'13'}), items_add=frozenset({'15'}), confidence=0.5, lift=16.666666666666668), OrderedStatistic(items_base=frozenset({'15'}), items_add=frozenset({'13'}), confidence=0.33333333333333337, lift=16.666666666666668)]),
#  RelationRecord(items=frozenset({'171', '13'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'13'}), items_add=frozenset({'171'}), confidence=0.25, lift=50.0), OrderedStatistic(items_base=frozenset({'171'}), items_add=frozenset({'13'}), confidence=1.0, lift=50.0)]),
#  RelationRecord(items=frozenset({'175', '13'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'13'}), items_add=frozenset({'175'}), confidence=0.25, lift=50.0), OrderedStatistic(items_base=frozenset({'175'}), items_add=frozenset({'13'}), confidence=1.0, lift=50.0)]),
#  RelationRecord(items=frozenset({'20', '13'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'13'}), items_add=frozenset({'20'}), confidence=0.5, lift=8.333333333333334)]),
#  RelationRecord(items=frozenset({'37', '13'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'13'}), items_add=frozenset({'37'}), confidence=0.25, lift=8.333333333333334)]),
#  RelationRecord(items=frozenset({'40', '13'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'13'}), items_add=frozenset({'40'}), confidence=0.25, lift=3.571428571428571)]),
#  RelationRecord(items=frozenset({'52', '13'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'13'}), items_add=frozenset({'52'}), confidence=0.25, lift=6.25)]),
#  RelationRecord(items=frozenset({'58', '13'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'13'}), items_add=frozenset({'58'}), confidence=0.25, lift=7.142857142857142)]),
#  RelationRecord(items=frozenset({'87', '13'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'13'}), items_add=frozenset({'87'}), confidence=0.25, lift=5.555555555555555)]),
#  RelationRecord(items=frozenset({'88', '13'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'13'}), items_add=frozenset({'88'}), confidence=0.25, lift=6.25)]),
#  RelationRecord(items=frozenset({'130', '38'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'130'}), items_add=frozenset({'38'}), confidence=1.0, lift=22.22222222222222)]),
#  RelationRecord(items=frozenset({'71', '130'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'130'}), items_add=frozenset({'71'}), confidence=1.0, lift=25.0)]),
#  RelationRecord(items=frozenset({'130', '75'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'130'}), items_add=frozenset({'75'}), confidence=1.0, lift=25.0)]),
#  RelationRecord(items=frozenset({'47', '131'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'131'}), items_add=frozenset({'47'}), confidence=1.0, lift=16.666666666666668)]),
#  RelationRecord(items=frozenset({'71', '131'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'131'}), items_add=frozenset({'71'}), confidence=1.0, lift=25.0)]),
#  RelationRecord(items=frozenset({'9', '131'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'131'}), items_add=frozenset({'9'}), confidence=1.0, lift=100.0), OrderedStatistic(items_base=frozenset({'9'}), items_add=frozenset({'131'}), confidence=0.5, lift=100.0)]),
#  RelationRecord(items=frozenset({'132', '39'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'132'}), items_add=frozenset({'39'}), confidence=1.0, lift=20.0)]),
#  RelationRecord(items=frozenset({'71', '132'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'132'}), items_add=frozenset({'71'}), confidence=1.0, lift=25.0)]),
#  RelationRecord(items=frozenset({'132', '75'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'132'}), items_add=frozenset({'75'}), confidence=1.0, lift=25.0)]),
#  RelationRecord(items=frozenset({'133', '25'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'133'}), items_add=frozenset({'25'}), confidence=1.0, lift=33.333333333333336)]),
#  RelationRecord(items=frozenset({'34', '133'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'133'}), items_add=frozenset({'34'}), confidence=1.0, lift=22.22222222222222)]),
#  RelationRecord(items=frozenset({'133', '72'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'133'}), items_add=frozenset({'72'}), confidence=1.0, lift=40.0)]),
#  RelationRecord(items=frozenset({'134', '31'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'134'}), items_add=frozenset({'31'}), confidence=1.0, lift=20.0)]),
#  RelationRecord(items=frozenset({'71', '134'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'134'}), items_add=frozenset({'71'}), confidence=1.0, lift=25.0)]),
#  RelationRecord(items=frozenset({'134', '72'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'134'}), items_add=frozenset({'72'}), confidence=1.0, lift=40.0)]),
#  RelationRecord(items=frozenset({'135', '20'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'135'}), items_add=frozenset({'20'}), confidence=1.0, lift=16.666666666666668)]),
#  RelationRecord(items=frozenset({'135', '5'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'135'}), items_add=frozenset({'5'}), confidence=1.0, lift=40.0)]),
#  RelationRecord(items=frozenset({'135', '73'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'135'}), items_add=frozenset({'73'}), confidence=1.0, lift=20.0)]),
#  RelationRecord(items=frozenset({'29', '136'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'136'}), items_add=frozenset({'29'}), confidence=1.0, lift=22.22222222222222)]),
#  RelationRecord(items=frozenset({'73', '136'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'136'}), items_add=frozenset({'73'}), confidence=1.0, lift=20.0)]),
#  RelationRecord(items=frozenset({'88', '136'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'136'}), items_add=frozenset({'88'}), confidence=1.0, lift=25.0)]),
#  RelationRecord(items=frozenset({'137', '18'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'137'}), items_add=frozenset({'18'}), confidence=0.5, lift=12.5)]),
#  RelationRecord(items=frozenset({'137', '199'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'137'}), items_add=frozenset({'199'}), confidence=0.5, lift=100.0), OrderedStatistic(items_base=frozenset({'199'}), items_add=frozenset({'137'}), confidence=1.0, lift=100.0)]),
#  RelationRecord(items=frozenset({'137', '32'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'137'}), items_add=frozenset({'32'}), confidence=0.5, lift=7.142857142857142)]),
#  RelationRecord(items=frozenset({'44', '137'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'137'}), items_add=frozenset({'44'}), confidence=0.5, lift=16.666666666666668)]),
#  RelationRecord(items=frozenset({'137', '7'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'137'}), items_add=frozenset({'7'}), confidence=0.5, lift=50.0), OrderedStatistic(items_base=frozenset({'7'}), items_add=frozenset({'137'}), confidence=0.5, lift=50.0)]),
#  RelationRecord(items=frozenset({'137', '73'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'137'}), items_add=frozenset({'73'}), confidence=0.5, lift=10.0)]),
#  RelationRecord(items=frozenset({'32', '138'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'138'}), items_add=frozenset({'32'}), confidence=1.0, lift=14.285714285714285)]),
#  RelationRecord(items=frozenset({'73', '138'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'138'}), items_add=frozenset({'73'}), confidence=1.0, lift=20.0)]),
#  RelationRecord(items=frozenset({'139', '19'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'139'}), items_add=frozenset({'19'}), confidence=1.0, lift=15.384615384615383)]),
#  RelationRecord(items=frozenset({'139', '74'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'139'}), items_add=frozenset({'74'}), confidence=1.0, lift=40.0)]),
#  RelationRecord(items=frozenset({'14', '179'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'179'}), items_add=frozenset({'14'}), confidence=1.0, lift=40.0)]),
#  RelationRecord(items=frozenset({'35', '140'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'140'}), items_add=frozenset({'35'}), confidence=1.0, lift=15.384615384615383)]),
#  RelationRecord(items=frozenset({'140', '72'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'140'}), items_add=frozenset({'72'}), confidence=1.0, lift=40.0)]),
#  RelationRecord(items=frozenset({'74', '140'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'140'}), items_add=frozenset({'74'}), confidence=1.0, lift=40.0)]),
#  RelationRecord(items=frozenset({'141', '5'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'141'}), items_add=frozenset({'5'}), confidence=1.0, lift=40.0)]),
#  RelationRecord(items=frozenset({'141', '57'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'141'}), items_add=frozenset({'57'}), confidence=1.0, lift=28.57142857142857)]),
#  RelationRecord(items=frozenset({'141', '75'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'141'}), items_add=frozenset({'75'}), confidence=1.0, lift=25.0)]),
#  RelationRecord(items=frozenset({'142', '32'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'142'}), items_add=frozenset({'32'}), confidence=1.0, lift=14.285714285714285)]),
#  RelationRecord(items=frozenset({'142', '75'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'142'}), items_add=frozenset({'75'}), confidence=1.0, lift=25.0)]),
#  RelationRecord(items=frozenset({'93', '142'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'142'}), items_add=frozenset({'93'}), confidence=1.0, lift=40.0)]),
#  RelationRecord(items=frozenset({'28', '143'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'143'}), items_add=frozenset({'28'}), confidence=1.0, lift=20.0)]),
#  RelationRecord(items=frozenset({'40', '143'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'143'}), items_add=frozenset({'40'}), confidence=1.0, lift=14.285714285714285)]),
#  RelationRecord(items=frozenset({'143', '76'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'143'}), items_add=frozenset({'76'}), confidence=1.0, lift=40.0)]),
#  RelationRecord(items=frozenset({'144', '32'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'144'}), items_add=frozenset({'32'}), confidence=1.0, lift=14.285714285714285)]),
#  RelationRecord(items=frozenset({'144', '76'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'144'}), items_add=frozenset({'76'}), confidence=1.0, lift=40.0)]),
#  RelationRecord(items=frozenset({'87', '144'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'144'}), items_add=frozenset({'87'}), confidence=1.0, lift=22.22222222222222)]),
#  RelationRecord(items=frozenset({'145', '25'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'145'}), items_add=frozenset({'25'}), confidence=1.0, lift=33.333333333333336)]),
#  RelationRecord(items=frozenset({'145', '77'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'145'}), items_add=frozenset({'77'}), confidence=1.0, lift=25.0)]),
#  RelationRecord(items=frozenset({'28', '146'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'146'}), items_add=frozenset({'28'}), confidence=1.0, lift=20.0)]),
#  RelationRecord(items=frozenset({'77', '146'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'146'}), items_add=frozenset({'77'}), confidence=1.0, lift=25.0)]),
#  RelationRecord(items=frozenset({'97', '146'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'146'}), items_add=frozenset({'97'}), confidence=1.0, lift=40.0)]),
#  RelationRecord(items=frozenset({'147', '36'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'147'}), items_add=frozenset({'36'}), confidence=1.0, lift=22.22222222222222)]),
#  RelationRecord(items=frozenset({'147', '48'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'147'}), items_add=frozenset({'48'}), confidence=1.0, lift=12.5)]),
#  RelationRecord(items=frozenset({'77', '147'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'147'}), items_add=frozenset({'77'}), confidence=1.0, lift=25.0)]),
#  RelationRecord(items=frozenset({'148', '32'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'148'}), items_add=frozenset({'32'}), confidence=1.0, lift=14.285714285714285)]),
#  RelationRecord(items=frozenset({'148', '74'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'148'}), items_add=frozenset({'74'}), confidence=1.0, lift=40.0)]),
#  RelationRecord(items=frozenset({'148', '77'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'148'}), items_add=frozenset({'77'}), confidence=1.0, lift=25.0)]),
#  RelationRecord(items=frozenset({'22', '149'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'149'}), items_add=frozenset({'22'}), confidence=1.0, lift=40.0)]),
#  RelationRecord(items=frozenset({'34', '149'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'149'}), items_add=frozenset({'34'}), confidence=1.0, lift=22.22222222222222)]),
#  RelationRecord(items=frozenset({'149', '78'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'149'}), items_add=frozenset({'78'}), confidence=1.0, lift=15.384615384615383)]),
#  RelationRecord(items=frozenset({'15', '177'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'177'}), items_add=frozenset({'15'}), confidence=1.0, lift=33.333333333333336)]),
#  RelationRecord(items=frozenset({'15', '183'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'183'}), items_add=frozenset({'15'}), confidence=1.0, lift=33.333333333333336)]),
#  RelationRecord(items=frozenset({'15', '2'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'2'}), items_add=frozenset({'15'}), confidence=1.0, lift=33.333333333333336)]),
#  RelationRecord(items=frozenset({'15', '20'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'15'}), items_add=frozenset({'20'}), confidence=0.33333333333333337, lift=5.555555555555556)]),
#  RelationRecord(items=frozenset({'15', '58'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'15'}), items_add=frozenset({'58'}), confidence=0.33333333333333337, lift=9.523809523809524), OrderedStatistic(items_base=frozenset({'58'}), items_add=frozenset({'15'}), confidence=0.2857142857142857, lift=9.523809523809524)]),
# ...
#  RelationRecord(items=frozenset({'51', '57'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'51'}), items_add=frozenset({'57'}), confidence=0.33333333333333337, lift=9.523809523809524), OrderedStatistic(items_base=frozenset({'57'}), items_add=frozenset({'51'}), confidence=0.2857142857142857, lift=9.523809523809524)]),
#  RelationRecord(items=frozenset({'52', '60'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'52'}), items_add=frozenset({'60'}), confidence=0.25, lift=3.846153846153846)]),
#  RelationRecord(items=frozenset({'52', '63'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'52'}), items_add=frozenset({'63'}), confidence=0.25, lift=5.0)]),
#  RelationRecord(items=frozenset({'52', '96'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'96'}), items_add=frozenset({'52'}), confidence=1.0, lift=25.0)]),
#  RelationRecord(items=frozenset({'54', '53'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'53'}), items_add=frozenset({'54'}), confidence=0.5, lift=5.2631578947368425)]),
#  RelationRecord(items=frozenset({'60', '53'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'53'}), items_add=frozenset({'60'}), confidence=0.25, lift=3.846153846153846)]),
#  RelationRecord(items=frozenset({'77', '53'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'53'}), items_add=frozenset({'77'}), confidence=0.25, lift=6.25)]),
#  RelationRecord(items=frozenset({'57', '54'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'57'}), items_add=frozenset({'54'}), confidence=0.2857142857142857, lift=3.007518796992481)]),
#  RelationRecord(items=frozenset({'80', '54'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'80'}), items_add=frozenset({'54'}), confidence=1.0, lift=10.526315789473685)]),
#  RelationRecord(items=frozenset({'82', '54'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'82'}), items_add=frozenset({'54'}), confidence=0.5, lift=5.2631578947368425)]),
#  RelationRecord(items=frozenset({'83', '54'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'83'}), items_add=frozenset({'54'}), confidence=0.5, lift=5.2631578947368425)]),
#  RelationRecord(items=frozenset({'84', '54'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'84'}), items_add=frozenset({'54'}), confidence=1.0, lift=10.526315789473685)]),
#  RelationRecord(items=frozenset({'57', '55'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'55'}), items_add=frozenset({'57'}), confidence=0.22222222222222224, lift=6.349206349206349), OrderedStatistic(items_base=frozenset({'57'}), items_add=frozenset({'55'}), confidence=0.2857142857142857, lift=6.349206349206349)]),
#  RelationRecord(items=frozenset({'55', '62'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'55'}), items_add=frozenset({'62'}), confidence=0.22222222222222224, lift=6.349206349206349), OrderedStatistic(items_base=frozenset({'62'}), items_add=frozenset({'55'}), confidence=0.2857142857142857, lift=6.349206349206349)]),
#  RelationRecord(items=frozenset({'68', '55'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'68'}), items_add=frozenset({'55'}), confidence=0.25, lift=5.555555555555555)]),
#  RelationRecord(items=frozenset({'82', '55'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'82'}), items_add=frozenset({'55'}), confidence=0.5, lift=11.11111111111111)]),
#  RelationRecord(items=frozenset({'91', '55'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'91'}), items_add=frozenset({'55'}), confidence=0.33333333333333337, lift=7.407407407407408)]),
#  RelationRecord(items=frozenset({'85', '57'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'85'}), items_add=frozenset({'57'}), confidence=0.25, lift=7.142857142857142)]),
#  RelationRecord(items=frozenset({'69', '58'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'58'}), items_add=frozenset({'69'}), confidence=0.2857142857142857, lift=9.523809523809524), OrderedStatistic(items_base=frozenset({'69'}), items_add=frozenset({'58'}), confidence=0.33333333333333337, lift=9.523809523809524)]),
#  RelationRecord(items=frozenset({'58', '89'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'89'}), items_add=frozenset({'58'}), confidence=0.5, lift=14.285714285714285)]),
#  RelationRecord(items=frozenset({'90', '58'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'90'}), items_add=frozenset({'58'}), confidence=0.33333333333333337, lift=9.523809523809524)]),
#  RelationRecord(items=frozenset({'64', '59'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'64'}), items_add=frozenset({'59'}), confidence=0.25, lift=4.166666666666667)]),
#  RelationRecord(items=frozenset({'66', '59'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'66'}), items_add=frozenset({'59'}), confidence=0.25, lift=4.166666666666667)]),
#  RelationRecord(items=frozenset({'68', '59'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'68'}), items_add=frozenset({'59'}), confidence=0.25, lift=4.166666666666667)]),
#  RelationRecord(items=frozenset({'91', '59'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'91'}), items_add=frozenset({'59'}), confidence=0.33333333333333337, lift=5.555555555555556)]),
#  RelationRecord(items=frozenset({'92', '59'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'92'}), items_add=frozenset({'59'}), confidence=0.25, lift=4.166666666666667)]),
#  RelationRecord(items=frozenset({'7', '6'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'6'}), items_add=frozenset({'7'}), confidence=0.33333333333333337, lift=33.333333333333336), OrderedStatistic(items_base=frozenset({'7'}), items_add=frozenset({'6'}), confidence=0.5, lift=33.333333333333336)]),
#  RelationRecord(items=frozenset({'6', '76'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'6'}), items_add=frozenset({'76'}), confidence=0.33333333333333337, lift=13.333333333333334)]),
#  RelationRecord(items=frozenset({'60', '89'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'89'}), items_add=frozenset({'60'}), confidence=0.5, lift=7.692307692307692)]),
#  RelationRecord(items=frozenset({'60', '94'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'94'}), items_add=frozenset({'60'}), confidence=0.5, lift=7.692307692307692)]),
#  RelationRecord(items=frozenset({'95', '60'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'95'}), items_add=frozenset({'60'}), confidence=0.33333333333333337, lift=5.128205128205129)]),
#  RelationRecord(items=frozenset({'96', '60'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'96'}), items_add=frozenset({'60'}), confidence=1.0, lift=15.384615384615383)]),
#  RelationRecord(items=frozenset({'98', '60'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'98'}), items_add=frozenset({'60'}), confidence=0.25, lift=3.846153846153846)]),
#  RelationRecord(items=frozenset({'61', '99'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99'}), items_add=frozenset({'61'}), confidence=0.25, lift=10.0)]),
#  RelationRecord(items=frozenset({'63', '65'}), support=0.015, ordered_statistics=[OrderedStatistic(items_base=frozenset({'63'}), items_add=frozenset({'65'}), confidence=0.3, lift=7.5), OrderedStatistic(items_base=frozenset({'65'}), items_add=frozenset({'63'}), confidence=0.375, lift=7.5)]),
#  RelationRecord(items=frozenset({'63', '66'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'66'}), items_add=frozenset({'63'}), confidence=0.5, lift=10.0)]),
#  RelationRecord(items=frozenset({'63', '68'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'68'}), items_add=frozenset({'63'}), confidence=0.25, lift=5.0)]),
#  RelationRecord(items=frozenset({'9', '64'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'64'}), items_add=frozenset({'9'}), confidence=0.25, lift=25.0), OrderedStatistic(items_base=frozenset({'9'}), items_add=frozenset({'64'}), confidence=0.5, lift=25.0)]),
#  RelationRecord(items=frozenset({'83', '67'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'83'}), items_add=frozenset({'67'}), confidence=0.5, lift=11.11111111111111)]),
#  RelationRecord(items=frozenset({'91', '68'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'68'}), items_add=frozenset({'91'}), confidence=0.25, lift=16.666666666666668), OrderedStatistic(items_base=frozenset({'91'}), items_add=frozenset({'68'}), confidence=0.33333333333333337, lift=16.666666666666668)]),
#  RelationRecord(items=frozenset({'69', '91'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'91'}), items_add=frozenset({'69'}), confidence=0.33333333333333337, lift=11.111111111111112)]),
#  RelationRecord(items=frozenset({'7', '73'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'7'}), items_add=frozenset({'73'}), confidence=0.5, lift=10.0)]),
#  RelationRecord(items=frozenset({'71', '75'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'71'}), items_add=frozenset({'75'}), confidence=0.25, lift=6.25), OrderedStatistic(items_base=frozenset({'75'}), items_add=frozenset({'71'}), confidence=0.25, lift=6.25)]),
#  RelationRecord(items=frozenset({'9', '71'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'9'}), items_add=frozenset({'71'}), confidence=0.5, lift=12.5)]),
#  RelationRecord(items=frozenset({'71', '95'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'95'}), items_add=frozenset({'71'}), confidence=0.33333333333333337, lift=8.333333333333334)]),
#  RelationRecord(items=frozenset({'85', '75'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'85'}), items_add=frozenset({'75'}), confidence=0.25, lift=6.25)]),
#  RelationRecord(items=frozenset({'78', '89'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'89'}), items_add=frozenset({'78'}), confidence=0.5, lift=7.692307692307692)]),
#  RelationRecord(items=frozenset({'90', '78'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'90'}), items_add=frozenset({'78'}), confidence=0.33333333333333337, lift=5.128205128205129)]),
#  RelationRecord(items=frozenset({'83', '79'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'83'}), items_add=frozenset({'79'}), confidence=0.5, lift=20.0)]),
#  RelationRecord(items=frozenset({'94', '8'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'8'}), items_add=frozenset({'94'}), confidence=0.5, lift=50.0), OrderedStatistic(items_base=frozenset({'94'}), items_add=frozenset({'8'}), confidence=0.5, lift=50.0)]),
#  RelationRecord(items=frozenset({'95', '86'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'95'}), items_add=frozenset({'86'}), confidence=0.33333333333333337, lift=13.333333333333334)]),
#  RelationRecord(items=frozenset({'92', '87'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'92'}), items_add=frozenset({'87'}), confidence=0.25, lift=5.555555555555555)]),
#  RelationRecord(items=frozenset({'98', '88'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'98'}), items_add=frozenset({'88'}), confidence=0.25, lift=6.25)]),
#  RelationRecord(items=frozenset({'90', '93'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'90'}), items_add=frozenset({'93'}), confidence=0.33333333333333337, lift=13.333333333333334)]),
#  RelationRecord(items=frozenset({'99', '97'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'99'}), items_add=frozenset({'97'}), confidence=0.25, lift=10.0)]),
#  RelationRecord(items=frozenset({'Annual Income (k$)', 'Age'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Age'}), items_add=frozenset({'Annual Income (k$)'}), confidence=1.0, lift=200.0), OrderedStatistic(items_base=frozenset({'Annual Income (k$)'}), items_add=frozenset({'Age'}), confidence=1.0, lift=200.0)]),
#  RelationRecord(items=frozenset({'Age', 'CustomerID'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Age'}), items_add=frozenset({'CustomerID'}), confidence=1.0, lift=200.0), OrderedStatistic(items_base=frozenset({'CustomerID'}), items_add=frozenset({'Age'}), confidence=1.0, lift=200.0)]),
#  RelationRecord(items=frozenset({'Age', 'Gender'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Age'}), items_add=frozenset({'Gender'}), confidence=1.0, lift=200.0), OrderedStatistic(items_base=frozenset({'Gender'}), items_add=frozenset({'Age'}), confidence=1.0, lift=200.0)]),
#  RelationRecord(items=frozenset({'Age', 'Spending Score (1-100)'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Age'}), items_add=frozenset({'Spending Score (1-100)'}), confidence=1.0, lift=200.0), OrderedStatistic(items_base=frozenset({'Spending Score (1-100)'}), items_add=frozenset({'Age'}), confidence=1.0, lift=200.0)]),
#  RelationRecord(items=frozenset({'Annual Income (k$)', 'CustomerID'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Annual Income (k$)'}), items_add=frozenset({'CustomerID'}), confidence=1.0, lift=200.0), OrderedStatistic(items_base=frozenset({'CustomerID'}), items_add=frozenset({'Annual Income (k$)'}), confidence=1.0, lift=200.0)]),
#  RelationRecord(items=frozenset({'Annual Income (k$)', 'Gender'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Annual Income (k$)'}), items_add=frozenset({'Gender'}), confidence=1.0, lift=200.0), OrderedStatistic(items_base=frozenset({'Gender'}), items_add=frozenset({'Annual Income (k$)'}), confidence=1.0, lift=200.0)]),
#  RelationRecord(items=frozenset({'Annual Income (k$)', 'Spending Score (1-100)'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Annual Income (k$)'}), items_add=frozenset({'Spending Score (1-100)'}), confidence=1.0, lift=200.0), OrderedStatistic(items_base=frozenset({'Spending Score (1-100)'}), items_add=frozenset({'Annual Income (k$)'}), confidence=1.0, lift=200.0)]),
#  RelationRecord(items=frozenset({'CustomerID', 'Gender'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'CustomerID'}), items_add=frozenset({'Gender'}), confidence=1.0, lift=200.0), OrderedStatistic(items_base=frozenset({'Gender'}), items_add=frozenset({'CustomerID'}), confidence=1.0, lift=200.0)]),
#  RelationRecord(items=frozenset({'CustomerID', 'Spending Score (1-100)'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'CustomerID'}), items_add=frozenset({'Spending Score (1-100)'}), confidence=1.0, lift=200.0), OrderedStatistic(items_base=frozenset({'Spending Score (1-100)'}), items_add=frozenset({'CustomerID'}), confidence=1.0, lift=200.0)]),
#  RelationRecord(items=frozenset({'Spending Score (1-100)', 'Gender'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Gender'}), items_add=frozenset({'Spending Score (1-100)'}), confidence=1.0, lift=200.0), OrderedStatistic(items_base=frozenset({'Spending Score (1-100)'}), items_add=frozenset({'Gender'}), confidence=1.0, lift=200.0)])]

# %% [markdown]
# ### Putting the results well organised into a Pandas DataFrame

# %%
def inspect(results):
    lhs         = [tuple(result[2][0][0])[0] for result in results]
    rhs         = [tuple(result[2][0][1])[0] for result in results]
    supports    = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts       = [result[2][0][3] for result in results]
    return list(zip(lhs, rhs, supports, confidences, lifts))
resultsinDataFrame = pd.DataFrame(inspect(results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %% [markdown]
# ### Displaying the results non sorted

# %%
resultsinDataFrame
# Out:
#          Left Hand Side         Right Hand Side  Support  Confidence  \
# 0                     1                      15    0.005    0.333333
# 1                     1                     157    0.005    0.333333
# 2                     1                     159    0.005    0.333333
# 3                     1                      19    0.005    0.333333
# 4                     1                      34    0.005    0.333333
# ..                  ...                     ...      ...         ...
# 544  Annual Income (k$)                  Gender    0.005    1.000000
# 545  Annual Income (k$)  Spending Score (1-100)    0.005    1.000000
# 546          CustomerID                  Gender    0.005    1.000000
# 547          CustomerID  Spending Score (1-100)    0.005    1.000000
# 548              Gender  Spending Score (1-100)    0.005    1.000000
#
#            Lift
# 0     11.111111
# 1     66.666667
# 2     66.666667
# 3      5.128205
# 4      7.407407
# ..          ...
# 544  200.000000
# 545  200.000000
# 546  200.000000
# 547  200.000000
# 548  200.000000
#
# [549 rows x 5 columns]

# %% [markdown]
# ### Displaying the results sorted by descending lifts

# %%
resultsinDataFrame.nlargest(n = 10, columns = 'Lift')
# Out:
#          Left Hand Side         Right Hand Side  Support  Confidence   Lift
# 539                 Age      Annual Income (k$)    0.005         1.0  200.0
# 540                 Age              CustomerID    0.005         1.0  200.0
# 541                 Age                  Gender    0.005         1.0  200.0
# 542                 Age  Spending Score (1-100)    0.005         1.0  200.0
# 543  Annual Income (k$)              CustomerID    0.005         1.0  200.0
# 544  Annual Income (k$)                  Gender    0.005         1.0  200.0
# 545  Annual Income (k$)  Spending Score (1-100)    0.005         1.0  200.0
# 546          CustomerID                  Gender    0.005         1.0  200.0
# 547          CustomerID  Spending Score (1-100)    0.005         1.0  200.0
# 548              Gender  Spending Score (1-100)    0.005         1.0  200.0
